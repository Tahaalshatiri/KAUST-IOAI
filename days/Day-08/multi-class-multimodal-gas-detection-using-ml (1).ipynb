Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1414_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1591_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/339_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/147_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/900_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1151_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/396_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1036_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/96_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1542_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1184_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/260_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/766_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1598_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1446_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/174_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/517_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/942_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1524_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/83_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1357_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/195_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/624_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1478_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/669_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/48_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/149_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1202_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1247_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/45_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/967_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/289_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/963_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/748_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/220_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1315_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/528_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/187_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/1484_Mixture.png
# /kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Thermal Camera Images/Mixture/209_Mixture.png

# %% [markdown]
# **The MultimodalGasData provides simultaneous measurements taken using seven different Gas Sensors and images taken using a Thermal Camera. Two different gases are considered, and a dataset is created for four classes – No Gas, Perfume, Smoke and Mixture of Perfume and Smoke. The dataset is collected using the seven different metal oxide gas sensors, MQ2, MQ3, MQ5, MQ6, MQ7, MQ8, MQ135 and a thermal imaging camera. The dataset consists of numerical values taken from gas sensors and images taken using a thermal camera.![dataset-cover.PNG](attachment:7ac4ed9b-84ac-480a-b4bb-82d86b2e6023.PNG)**

# %% [markdown]
# # Importing Package

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data profiling

# %%
df = pd.read_csv('/kaggle/input/multimodal-gas-detection-and-classification/Multimodal Dataset for Gas Detection and Classification/Gas Sensors Measurements/Gas_Sensors_Measurements.csv')

# %%
df.head()
# Out:
#    Serial Number  MQ2  MQ3  MQ5  MQ6  MQ7  MQ8  MQ135    Gas  \
# 0              0  555  515  377  338  666  451    416  NoGas
# 1              1  555  516  377  339  666  451    416  NoGas
# 2              2  556  517  376  337  666  451    416  NoGas
# 3              3  556  516  376  336  665  451    416  NoGas
# 4              4  556  516  376  337  665  451    416  NoGas
#
#   Corresponding Image Name
# 0                  0_NoGas
# 1                  1_NoGas
# 2                  2_NoGas
# 3                  3_NoGas
# 4                  4_NoGas

# %%
df.tail()
# Out:
#       Serial Number  MQ2  MQ3  MQ5  MQ6  MQ7  MQ8  MQ135      Gas  \
# 6395           1595  658  445  455  414  491  321    436  Mixture
# 6396           1596  650  444  451  411  486  317    431  Mixture
# 6397           1597  630  443  446  407  474  312    429  Mixture
# 6398           1598  632  443  444  405  471  309    430  Mixture
# 6399           1599  633  442  442  402  468  306    434  Mixture
#
#      Corresponding Image Name
# 6395             1595_Mixture
# 6396             1596_Mixture
# 6397             1597_Mixture
# 6398             1598_Mixture
# 6399             1599_Mixture

# %%
df.shape
# Out:
# (6400, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6400 entries, 0 to 6399
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Serial Number             6400 non-null   int64
#  1   MQ2                       6400 non-null   int64
#  2   MQ3                       6400 non-null   int64
#  3   MQ5                       6400 non-null   int64
#  4   MQ6                       6400 non-null   int64
#  5   MQ7                       6400 non-null   int64
#  6   MQ8                       6400 non-null   int64
#  7   MQ135                     6400 non-null   int64
#  8   Gas                       6400 non-null   object
#  9   Corresponding Image Name  6400 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 500.1+ KB

# %%
df.describe().T
# Out:
#                 count        mean         std    min     25%    50%      75%  \
# Serial Number  6400.0  799.500000  461.916214    0.0  399.75  799.5  1199.25
# MQ2            6400.0  677.593438   92.913955  502.0  591.00  701.0   756.00
# MQ3            6400.0  462.024688   70.284038  337.0  405.00  486.0   529.00
# MQ5            6400.0  404.579063   55.672249  291.0  366.00  400.0   443.00
# MQ6            6400.0  399.758750   45.091353  311.0  366.00  393.0   426.00
# MQ7            6400.0  565.952031   83.133693  361.0  524.00  576.0   629.00
# MQ8            6400.0  542.473750  151.020217  220.0  447.00  576.0   642.00
# MQ135          6400.0  416.727031   76.681407  275.0  354.00  437.0   473.00
#
#                   max
# Serial Number  1599.0
# MQ2             824.0
# MQ3             543.0
# MQ5             596.0
# MQ6             524.0
# MQ7             796.0
# MQ8             794.0
# MQ135           589.0

# %%
def data_profiling(df):
    data_profile = []
    columns = df.columns
    for col in columns:
        dtype = df[col].dtypes
        nunique = df[col].nunique()
        null = df[col].isnull().sum()
        duplicates = df[col].duplicated().sum()
        data_profile.append([col,dtype,nunique,null,duplicates])
    data_profile_finding = pd.DataFrame(data_profile)
    data_profile_finding.columns = ['column','dtype','nunique','null','duplicates']
    return data_profile_finding

# %%
data_profiling(df)
# Out:
#                      column   dtype  nunique  null  duplicates
# 0             Serial Number   int64     1600     0        4800
# 1                       MQ2   int64      322     0        6078
# 2                       MQ3   int64      152     0        6248
# 3                       MQ5   int64      263     0        6137
# 4                       MQ6   int64      204     0        6196
# 5                       MQ7   int64      351     0        6049
# 6                       MQ8   int64      557     0        5843
# 7                     MQ135   int64      314     0        6086
# 8                       Gas  object        4     0        6396
# 9  Corresponding Image Name  object     6400     0           0

# %%
df.isnull().sum()
# Out:
# Serial Number               0
# MQ2                         0
# MQ3                         0
# MQ5                         0
# MQ6                         0
# MQ7                         0
# MQ8                         0
# MQ135                       0
# Gas                         0
# Corresponding Image Name    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Serial Number               0
# MQ2                         0
# MQ3                         0
# MQ5                         0
# MQ6                         0
# MQ7                         0
# MQ8                         0
# MQ135                       0
# Gas                         0
# Corresponding Image Name    0
# dtype: int64

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
    print(df[df.columns[i]].unique())
    print('**' * 10)
# Out:
# Serial Number
# [   0    1    2 ... 1597 1598 1599]
# ********************
# MQ2
# [555 556 557 558 559 560 561 562 563 564 565 566 658 657 655 652 653 651
#  650 649 647 645 644 642 641 640 693 690 689 686 685 683 681 679 678 677
#  676 674 673 672 670 669 666 664 663 662 661 660 654 709 705 703 699 697
#  696 695 694 691 692 700 702 687 688 684 680 675 763 773 738 728 725 724
#  721 718 716 715 713 712 708 706 704 701 698 768 774 778 764 760 758 755
#  757 756 750 748 745 744 746 740 735 734 732 730 726 722 723 719 720 717
#  714 759 772 779 782 784 769 767 766 752 749 751 747 743 741 739 742 733
#  731 776 777 775 762 754 753 736 780 770 761 737 781 727 789 792 785 783
#  786 787 791 729 711 771 788 790 793 794 765 795 797 796 798 803 800 799
#  802 801 804 809 805 592 811 816 817 821 824 822 820 819 818 813 814 808
#  707 710 682 668 665 638 637 636 634 633 632 631 629 630 628 627 625 624
#  648 646 639 667 807 810 812 815 806 518 519 522 523 524 525 530 615 605
#  595 588 581 575 571 567 553 550 548 546 543 541 551 549 547 545 544 538
#  455 454 453 452 459 439 438 481 437 436 435 434 433 432 431 222 237 240
#  255 270 291 307 324 338 347 356 363 369 373 374 372 371 365 360 358 350
#  339 327 317 298 290 283 278 273 268 264 260 257 254 251 249 247 244 243
#  242 239 235 233 231 226 225 224 269 310 331 342 344 345 348 353 357 361
#  359 351 349 337 326 318 304 296 284 279 275 271 267 265 263 259 253 250
#  248 246 245 238 236 234 230 220 223 309 382 394 404 409 411 402 390 379
#  364 354 355 352 334 325 319 315 311 303 299 294 286 281 276 272 266 261
#  258 256 252 241 232 302 330 306 297 288 280 274 282 285 366 377 385 396
#  395 398 397 399 388 375 346 335 292 277 262 412 370 367 368 386 393 392
#  376 322 314 308 293 287 295 301 300 413 429 422 416 405 387 380 381 378
#  362 384 389 391 336 328 320 406 321 403 401 340 332 490 383 400 312 313
#  289 341 333 427 305 323 316 343 499 496 501 408 424 430 407 415 329]
# ********************
# MQ135
# [416 415 414 413 412 411 410 409 408 398 395 388 390 389 391 392 387 447
#  448 443 440 441 446 445 439 438 442 436 435 433 434 465 462 469 458 463
#  461 457 459 449 454 450 456 444 437 432 431 429 476 475 473 471 470 468
#  464 460 455 453 452 451 479 485 474 472 467 466 480 483 488 486 481 484
#  482 477 497 487 492 496 491 526 523 519 515 511 508 504 501 499 494 478
#  489 490 495 498 510 506 505 503 502 500 493 509 512 514 507 513 516 522
#  521 520 518 517 535 533 531 528 525 527 529 532 553 537 534 530 524 539
#  542 543 548 551 554 550 549 558 559 561 563 564 565 571 576 577 579 584
#  582 581 578 574 572 570 568 557 555 547 545 540 538 536 428 427 426 424
#  425 430 420 541 544 556 580 583 585 586 587 589 588 569 567 552 560 566
#  562 575 573 332 342 340 326 321 319 318 317 315 314 313 312 310 309 308
#  307 306 305 304 303 302 301 300 299 298 292 293 295 294 296 297 290 291
#  287 286 284 283 285 289 288 282 279 278 281 280 275 276 277 316 330 323
#  320 331 347 352 338 345 363 376 372 360 351 346 336 334 329 328 325 324
#  322 311 327 333 335 339 337 350 366 361 357 356 353 349 348 341 343 374
#  375 370 368 369 344 365 371 364 367 379 362 358 359 355 354 373 381 384
#  394 396 393 397 386 382 400 399 403 405 406 404 402 401 385 380 417 419
#  421 423 422 407 418 383 377 378]
# ********************
# Gas
# ['NoGas' 'Perfume' 'Smoke' 'Mixture']
# ********************
# Corresponding Image Name
# ['0_NoGas' '1_NoGas' '2_NoGas' ... '1597_Mixture' '1598_Mixture'
#  '1599_Mixture']
# ********************

# %%
for i in range(len(df.columns)):
    print(df.columns[i])
    print(df[df.columns[i]].value_counts())
    print('**' * 10)
# Out:
# Serial Number
# Serial Number
# 0       4
# 1063    4
# 1073    4
# 1072    4
# 1071    4
#        ..
# 530     4
# 529     4
# 528     4
# 527     4
# 1599    4
# Name: count, Length: 1600, dtype: int64
# ********************
# MQ2
# MQ2
# 738    64
# 739    57
# 740    56
# 793    53
# 794    53
#        ..
# 822     1
# 818     1
# 824     1
# 821     1
# 820     1
# Name: count, Length: 322, dtype: int64
# ********************
# MQ3
# MQ3
# 530    429
# 529    398
# 531    342
# 528    281
# 532    221
#       ...
# 338      1
# 460      1
# 543      1
# 337      1
# 512      1
# Name: count, Length: 152, dtype: int64
# ********************
# MQ5
# MQ5
# 406    79
# 409    70
# 407    63
# 410    63
# 404    60
#        ..
# 579     1
# 565     1
# 559     1
# 541     1
# 547     1
# Name: count, Length: 263, dtype: int64
# ********************
# MQ6
# MQ6
# 375    97
# 393    91
# 397    81
# 391    75
# 367    74
#        ..
# 515     2
# 521     2
# 318     1
# 323     1
# 315     1
# Name: count, Length: 204, dtype: int64
# ********************
# MQ7
# MQ7
# 576    152
# 575    133
# 574    132
# 572    114
# 581    101
#       ...
# 796      1
# 700      1
# 361      1
# 793      1
# 715      1
# Name: count, Length: 351, dtype: int64
# ********************
# MQ8
# MQ8
# 575    52
# 559    49
# 566    49
# 551    49
# 558    46
#        ..
# 459     1
# 461     1
# 462     1
# 465     1
# 224     1
# Name: count, Length: 557, dtype: int64
# ********************
# MQ135
# MQ135
# 284    89
# 280    71
# 442    69
# 439    64
# 283    62
#        ..
# 552     1
# 541     1
# 547     1
# 548     1
# 573     1
# Name: count, Length: 314, dtype: int64
# ********************
# Gas
# Gas
# NoGas      1600
# Perfume    1600
# Smoke      1600
# Mixture    1600
# Name: count, dtype: int64
# ********************
# Corresponding Image Name
# Corresponding Image Name
# 0_NoGas         1
# 1063_Smoke      1
# 1073_Smoke      1
# 1072_Smoke      1
# 1071_Smoke      1
#                ..
# 530_Perfume     1
# 529_Perfume     1
# 528_Perfume     1
# 527_Perfume     1
# 1599_Mixture    1
# Name: count, Length: 6400, dtype: int64
# ********************

# %% [markdown]
# ## NO NaN or Null value Present in this dataset

# %% [markdown]
# # Exploratory Data Analysis

# %%
numeric_features = [i for i in df.columns if df[i].dtype!='O']
categorical_features = [i for i in df.columns if df[i].dtype=='O']

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df,x='Gas',palette='Set2')
# Out:
# <Axes: xlabel='Gas', ylabel='count'>

# %%
plt.figure(figsize=(18,18))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(4, 2, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,data=df)
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# > Removing the columns Serial Number ,Corresponding Image Name

# %%
df.columns
# Out:
# Index(['Serial Number', 'MQ2', 'MQ3', 'MQ5', 'MQ6', 'MQ7', 'MQ8', 'MQ135',
#        'Gas', 'Corresponding Image Name'],
#       dtype='object')

# %%
df = df.drop([
            'Serial Number',
            'Corresponding Image Name',
            ],axis=1)

# %%
df.head()
# Out:
#    MQ2  MQ3  MQ5  MQ6  MQ7  MQ8  MQ135    Gas
# 0  555  515  377  338  666  451    416  NoGas
# 1  555  516  377  339  666  451    416  NoGas
# 2  556  517  376  337  666  451    416  NoGas
# 3  556  516  376  336  665  451    416  NoGas
# 4  556  516  376  337  665  451    416  NoGas

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
print(X.shape)
# Out:
# (6400, 7)

# %%
print(y.shape)
# Out:
# (6400,)

# %% [markdown]
# # Label Encoing Target Variable

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(y)
print(y)
# Out:
# [1 1 1 ... 0 0 0]

# %% [markdown]
# # Train-Test Split & Feature Scaling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size=0.3, random_state=1)

# %%
print(X_train.shape)
# Out:
# (4480, 7)

# %%
print(X_test.shape)
# Out:
# (1920, 7)

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# # Model Building

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,BernoulliNB
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay, \
                            precision_score, recall_score, f1_score, roc_auc_score,roc_curve,confusion_matrix
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# # Random Forest Classifier

# %%
rf = RandomForestClassifier()
#fit the data for train and test set
rf.fit(X_train, y_train)
#Predit the values for test data
rf_preds = rf.predict(X_test)

# %%
print(accuracy_score(y_test,rf_preds))
# Out:
# 0.971875

# %%
rf_matrix=confusion_matrix(y_test,rf_preds)
sns.heatmap(rf_matrix, annot=True, fmt='d',cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression(solver = "newton-cg", multi_class = "multinomial", max_iter= 500, n_jobs = -1)

lr.fit(X_train, y_train)

lr_preds = lr.predict(X_test)

# %%
print(classification_report(y_test,lr_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       462
#            1       0.63      0.71      0.67       461
#            2       0.69      0.61      0.65       494
#            3       1.00      1.00      1.00       503
#
#     accuracy                           0.83      1920
#    macro avg       0.83      0.83      0.83      1920
# weighted avg       0.83      0.83      0.83      1920

# %%
lr_matrix=confusion_matrix(y_test,lr_preds)
sns.heatmap(lr_matrix, annot=True, fmt='d',cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# # K-Nearest Neighbors

# %%
scores = []

for i in range(1,16):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    
    knn.fit(X_train,y_train)
    
    y_pred = knn.predict(X_test)

    scores.append(accuracy_score(y_test, y_pred))

# %%
plt.plot(range(1,16),scores)

# %%
kn = KNeighborsClassifier(n_neighbors=3)
kn.fit(X_train, y_train)
kn_preds = kn.predict(X_test)

# %%
print(accuracy_score(y_test,kn_preds))
# Out:
# 0.9708333333333333

# %%
kn_matrix=confusion_matrix(y_test,kn_preds)
sns.heatmap(kn_matrix, annot=True, fmt='d',cmap="BuPu")
# Out:
# <Axes: >

# %% [markdown]
# # Support Vector Machines

# %%
params_grid = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

# %%
svm_model = GridSearchCV(SVC(), params_grid, cv=5)
svm_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']},
#                          {'C': [1, 10, 100, 1000], 'kernel': ['linear']}])

# %%
print('Best score for training data:', svm_model.best_score_,"\n") 

print('Best C:',svm_model.best_estimator_.C,"\n") 
print('Best Kernel:',svm_model.best_estimator_.kernel,"\n")
print('Best Gamma:',svm_model.best_estimator_.gamma,"\n")

final_model = svm_model.best_estimator_
svm_pred = final_model.predict(X_test)
# Out:
# Best score for training data: 0.9109375
#
# Best C: 1000
#
# Best Kernel: rbf
#
# Best Gamma: 0.001

# %%
print(classification_report(y_test,svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       462
#            1       0.83      0.80      0.81       461
#            2       0.82      0.85      0.83       494
#            3       1.00      1.00      1.00       503
#
#     accuracy                           0.91      1920
#    macro avg       0.91      0.91      0.91      1920
# weighted avg       0.91      0.91      0.91      1920

# %%
svm_matrix=confusion_matrix(y_test,svm_pred)
sns.heatmap(svm_matrix, annot=True, fmt='d',cmap="Blues")
# Out:
# <Axes: >
